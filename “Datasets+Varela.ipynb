# %%
import pandas as pd
import numpy as np
import xlrd

# %%
from google.colab import files

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Primer DataSet
#
# Trata sobre el corportamiento de clientes de un banco intentado predecir si es probable que abandone o siga siendo cliente del banco
#
# Variables Interesantes:
#
# *   Puntaje de credito
# *   Ubicacion
# *   Tenencia
# *   Cantidad de productos
# *   Miembro Activo

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Bank-Customer-Attrition-Insights-Data.csv')

Columnas = ["Registro Unico",
"Id cliente",
"Apellido",
"Puntaje de crédito",
"Ubicación",
"Genero",
"Edad",
"Tenencia",
"Saldo",
"Cantidad de productos",
"Tiene tarjeta?",
"Miembro activo",
"Salario estimado",
"Abandono el banco",
"queja",
"puntuación de satisfacción",
"tipo de tarjeta",
"puntos ganados"]

df.columns = Columnas

df
# Out:
#       Registro Unico  Id cliente    Apellido  Puntaje de crédito Ubicación  \
# 0                  1    15598695      Fields                 619    France
# 1                  2    15649354    Johnston                 608     Spain
# 2                  3    15737556    Vasilyev                 502    France
# 3                  4    15671610      Hooper                 699    France
# 4                  5    15625092     Colombo                 850     Spain
# ...              ...         ...         ...                 ...       ...
# 9995            9996    15583480      Morgan                 771    France
# 9996            9997    15620341     Nwebube                 516    France
# 9997            9998    15613886    Trevisan                 709    France
# 9998            9999    15792916  Ositadimma                 772   Germany
# 9999           10000    15710408  Cunningham                 792    France
#
#       Genero  Edad  Tenencia      Saldo  Cantidad de productos  \
# ...

# %% [markdown]
# **Segundo DataSet**
#
# Trata de ventas en un shoppingm teniendo varias variables para analizar
#
# Variables Interesantes:
# *   Edad
# *   Producto comprado
# *   EL monto de compra
# *   Ubicacion
# *   Metodo de pago

# %%
shopping = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/shopping_trends.csv")
shopping
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
nombres = ["Id", "Edad cliente", "Sexo", "Articulo comprado", "Categoria","Importe (USD)","Ubicacion","Tamaño","Color","Temporada","Reseña", "Suscripto","Metodo de pago","Tipo de envio","Descuento aplicado","Codigo Promo","Compras Realizadas","Metodo de pago preferido","Frecuencias de compras"]

shopping.columns = nombres

shopping
# Out:
#         Id  Edad cliente    Sexo Articulo comprado    Categoria  \
# 0        1            55    Male            Blouse     Clothing
# 1        2            19    Male           Sweater     Clothing
# 2        3            50    Male             Jeans     Clothing
# 3        4            21    Male           Sandals     Footwear
# 4        5            45    Male            Blouse     Clothing
# ...    ...           ...     ...               ...          ...
# 3895  3896            40  Female            Hoodie     Clothing
# 3896  3897            52  Female          Backpack  Accessories
# 3897  3898            46  Female              Belt  Accessories
# 3898  3899            44  Female             Shoes     Footwear
# 3899  3900            52  Female           Handbag  Accessories
#
#       Importe (USD)      Ubicacion Tamaño      Color Temporada  Reseña  \
# 0                53       Kentucky      L       Gray    Winter     3.1
# ...

# %% [markdown]
# **Tercer DataSet**
#
# Trata de ventas en un cafe teniendo varias variables para analizar
#
# Variables Interesantes:
#
#
# *   fecha
# *   cantidad de productos vendidos
# *   ubicacion del local
# *   precio
# *   categoria de producto

# %%
coffe = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/Coffee Shop Sales.xlsx")

nombre_columnas = ["Id de transacción",
"Fecha de transacción",
"Hora de transacción",
"Cantidad de productos vendidos",
"Id de local",
"ubicación del local",
"Id producto",
"precio",
"categoría producto",
"tipo producto",
"detalle producto"]

coffe.columns = nombre_columnas

coffe
# Out:
#         Id de transacción Fecha de transacción Hora de transacción  \
# 0                       1           2023-01-01            07:06:11
# 1                       2           2023-01-01            07:08:56
# 2                       3           2023-01-01            07:14:04
# 3                       4           2023-01-01            07:20:24
# 4                       5           2023-01-01            07:22:41
# ...                   ...                  ...                 ...
# 149111             149452           2023-06-30            20:18:41
# 149112             149453           2023-06-30            20:25:10
# 149113             149454           2023-06-30            20:31:34
# 149114             149455           2023-06-30            20:57:19
# 149115             149456           2023-06-30            20:57:19
#
#         Cantidad de productos vendidos  Id de local ubicación del local  \
# 0                                    2            5     Lower Manhattan
# ...
